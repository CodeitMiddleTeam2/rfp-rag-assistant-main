# %%
# !pip install supabase psycopg2-binary openai
# !pip install supabase openai langchain pgvector
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 kB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 123.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 115.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 22.5 MB/s eta 0:00:00
# ...

# %%
# export SUPABASE_URL="https://cfgmhgqjtdyiwohtiaem.supabase.co"
# export SUPABASE_SERVICE_KEY="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImNmZ21oZ3FqdGR5aXdvaHRpYWVtIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NjYxMDM4NjUsImV4cCI6MjA4MTY3OTg2NX0.6HOq1c8MUZl_Dlx8EoKxmZnyqmCcNVSIq6KfEYJ_5oE"

# %%
from supabase import create_client
from dotenv import load_dotenv
import os

load_dotenv()

supabase = create_client(
    os.environ["SUPABASE_URL"],
    os.environ["SUPABASE_SERVICE_KEY"]
)

# 테스트 쿼리
res = supabase.table("documents").select("*").limit(1).execute()
print(res.data)
# Out:
# []

# %%
from openai import OpenAI

client = OpenAI()

def embed_text(text: str) -> list[float]:
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return response.data[0].embedding

# %%
text = "Supabase는 Postgres 기반의 오픈소스 BaaS이다."
embedding = embed_text(text)

supabase.table("documents").insert({
    "content": text,
    "embedding": embedding,
    "metadata": {
        "source": "manual",
        "lang": "ko"
    }
}).execute()
# Out:
# APIResponse(data=[{'id': '7b83915e-fda0-4719-b522-be80112115c0', 'content': 'Supabase는 Postgres 기반의 오픈소스 BaaS이다.', 'embedding': '[-0.05911784,0.03891454,0.046697445,0.0026514311,0.033188254,-0.06190033,-0.007682093,0.01370074,0.0006987731,-0.052504383,-0.030425927,0.009199357,0.007500626,-0.016110215,-0.029195985,0.024921436,0.008503734,-0.02482062,-0.057545125,-0.030143645,0.0065428847,-0.0331076,-0.009113664,0.004728217,0.011210613,-0.009411068,-0.009683268,-0.03804753,-0.047020055,-0.032845482,0.02941778,-0.033067275,0.02041501,0.009229601,0.055165894,0.014224978,0.033006787,0.03709987,-0.0006502559,0.005675877,0.017370401,-0.0071074483,-0.0071376925,-0.013216829,0.024538338,0.07464333,7.328768e-05,-0.019739551,0.019437106,-0.005554899,-0.04758462,0.029720223,0.014517341,-0.04935896,0.047786247,0.0013534396,0.012430473,0.047020055,0.03966057,0.014134244,-0.004508945,0.0045064245,-0.015807772,0.027764415,-0.009501801,0.014073756,-0.011200531,0.036313515,-0.036293354,0.006265644,0.0
# ...

# %%
pip install psycopg2-binary openai python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import os

conn = psycopg2.connect(
    host="db.cfgmhgqjtdyiwohtiaem.supabase.co",
    port=5432,                      # 🔑 direct session port
    dbname="postgres",
    user="postgres",
    password="PqnPYA52yBZUqgAB",
    sslmode="require"
)

cur = conn.cursor()

cur.execute("select now();")
print(cur.fetchone())

cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 4
#       1 import psycopg2
#       2 import os
# ----> 4 conn = psycopg2.connect(
#       5     host="db.cfgmhgqjtdyiwohtiaem.supabase.co",
#       6     port=5432,                      # 🔑 direct session port
#       7     dbname="postgres",
#       8     user="postgres",
#       9     password="PqnPYA52yBZUqgAB",
#      10     sslmode="require"
#      11 )
#      13 cur = conn.cursor()
#      15 cur.execute("select now();")
#
# File ~/rfp-rag-assistant-main/venv_ragas/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
# ...
